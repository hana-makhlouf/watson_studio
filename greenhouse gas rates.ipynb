# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Country or Area  Year  co2_gigagrams  hfc_gigagrams  methane_gigagrams  \
# 0       Australia  2012    397830.6047    7945.106379        111709.4988
# 1       Australia  2011    398161.3872    7512.150105        110274.7423
# 2       Australia  2010    399364.8191    6942.606891        109062.6389
# 3       Australia  2009    398668.7713    6353.309697        110806.5324
# 4       Australia  2008    399084.1509    5810.538264        113592.7600
#
#    pfc_gigagrams  sf6_gigagrams  n2o_gigagrams
# 0     253.697462     134.111252    25775.42951
# 1     259.250564     134.136620    25201.09362
# 2     243.764011     145.185945    24451.85748
# 3     307.886656     143.230925    24897.90320
# 4     381.135610     158.400094    25546.77744

# %%
import brunel

# %brunel data ('df_data_1') x(co2_gigagrams) y(methane_gigagrams) color(Year) :: width=800, height=300
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/static-file-content-delivery-network/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/static-file-content-delivery-network/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %%
# %brunel data('df_data_1') x(co2_gigagrams) y(n2o_gigagrams) chord size(#count) color(Year) :: width=500, height=400
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/static-file-content-delivery-network/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/static-file-content-delivery-network/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %%
body = client_86f97583e73d4064a3dac7ec77aeab9b.get_object(Bucket='firstproject-donotdelete-pr-vjlx7kuofxpoph',Key='Environment Statistics Database  Waste.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
#                       Metric Country or Area  Year     Value  \
# 0  Hazardous waste generated         Algeria  2003  325000.0
# 1  Hazardous waste generated         Algeria  1997  185000.0
# 2  Hazardous waste generated         Algeria  1995  185000.0
# 3  Hazardous waste generated         Andorra  2006     935.5
# 4  Hazardous waste generated         Andorra  2005     622.0
#
#                                      Value Footnotes    Unit
# 0                                                NaN  tonnes
# 1                                                NaN  tonnes
# 2                                                NaN  tonnes
# 3                                                NaN  tonnes
# 4  Starting with the exports in 2003, the data co...  tonnes

# %%
# %brunel data('df_data_2') treemap x(metric, year) color(value) mean(value) size(#count) tooltip(#all) :: width=900, length=600)
# Out:
# ---------------------------------------------------------------------------
# java.lang.RuntimeExceptionPyRaisable      Traceback (most recent call last)
# <ipython-input-42-f7d02fb29c0d> in <module>
# ----> 1 get_ipython().run_line_magic('brunel', "data('df_data_2') treemap x(metric, year) color(country or area)  size(#count) tooltip(#all) :: width=900, length=600)")
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2285                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2286             with self.builtin_trap:
# -> 2287                 result = fn(*args,**kwargs)
#    2288             return result
#    2289
#
# </opt/conda/envs/Python36/lib/python3.6/site-packages/decorator.py:decorator-gen-125> in brunel(self, line, cell)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
# ...
